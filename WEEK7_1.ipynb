# %% [markdown]
# <a href="https://colab.research.google.com/github/AMJAMAITHILI/DL_LAB/blob/main/WEEK7_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Dense, Dropout, BatchNormalization
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i])
    plt.title(f"Label: {y_train[i][0]}")
    plt.axis('off')
plt.show()

x_train_main = x_train[:40000]
y_train_main = y_train[:40000]

x_val = x_train[40000:]
y_val = y_train[40000:]

x_train_main = x_train_main / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

y_train_main = keras.utils.to_categorical(y_train_main, 10)
y_val = keras.utils.to_categorical(y_val, 10)
y_test = keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %% [markdown]
# **LeNet**

# %%
model = Sequential()

model.add(Conv2D(6, kernel_size=(5,5), activation='tanh', input_shape=(32,32,3)))
model.add(AveragePooling2D((2,2)))

model.add(Conv2D(16, kernel_size=(5,5), activation='tanh'))
model.add(AveragePooling2D((2,2)))

model.add(Flatten())

model.add(Dense(120, activation='tanh'))
model.add(Dense(84, activation='tanh'))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()

model.fit(x_train_main, y_train_main, epochs=10, batch_size=128, validation_data=(x_val, y_val))

test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 6)      │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 14, 14, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_3             │ (None, 5, 5, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 62,006 (242.21 KB)
#  Trainable params: 62,006 (242.21 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 105ms/step - accuracy: 0.3345 - loss: 1.8652 - val_accuracy: 0.3805 - val_loss: 1.7608
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 31s 99ms/step - accuracy: 0.4038 - loss: 1.6939 - val_accuracy: 0.4133 - val_loss: 1.6566
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.4411 - loss: 1.5810 - val_accuracy: 0.4397 - val_loss: 1.5799
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.4723 - loss: 1.4833 - val_accuracy: 0.4731 - val_loss: 1.4736
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 30s 96ms/step - accuracy: 0.4982 - loss: 1.4107 - val_accuracy: 0.4888 - val_loss: 1.4450
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.5163 - loss: 1.3606 - val_accuracy: 0.5023 - val_loss: 1.3953
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.5359 - loss: 1.3118 - val_accuracy: 0.5055 - val_loss: 1.3988
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - accuracy: 0.5497 - loss: 1.2709 - val_accuracy: 0.5189 - val_loss: 1.3560
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 26s 82ms/step - accuracy: 0.5633 - loss: 1.2367 - val_accuracy: 0.5267 - val_loss: 1.3352
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 80ms/step - accuracy: 0.5745 - loss: 1.2074 - val_accuracy: 0.5319 - val_loss: 1.3301
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5315 - loss: 1.3188
# Test accuracy: 0.531499981880188

# %% [markdown]
# **AlexNet**

# %%
model = Sequential()

model.add(Conv2D(96, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(384, (3,3), activation='relu'))
model.add(Conv2D(384, (3,3), activation='relu'))
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train_main, y_train_main, epochs=20, batch_size=128, validation_data=(x_val, y_val))

model.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4715/2070459908.py in <cell line: 0>()
#      24 model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#      25
# ---> 26 model.fit(x_train_main, y_train_main, epochs=20, batch_size=128, validation_data=(x_val, y_val))
#      27
#      28 model.evaluate(x_test, y_test)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#     125
#     126     return error_handler
#
# ValueError: Exception encountered when calling Conv2D.call().
#
# Negative dimension size caused by subtracting 3 from 2 for '{{node sequential_2_1/conv2d_8_1/convolution}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](sequential_2_1/conv2d_7_1/Relu, sequential_2_1/conv2d_8_1/convolution/ReadVariableOp)' with input shapes: [?,2,2,384], [3,3,384,256].
#
# Arguments received by Conv2D.call():
#   • inputs=tf.Tensor(shape=(None, 2, 2, 384), dtype=float32)

# %%
model = Sequential()

model.add(Conv2D(96, (3,3), activation='relu', padding='same', input_shape=(32,32,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(384, (3,3), activation='relu', padding='same'))
model.add(Conv2D(384, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train_main, y_train_main, epochs=10, batch_size=128, validation_data=(x_val, y_val))

model.evaluate(x_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 78ms/step - accuracy: 0.2758 - loss: 1.9281 - val_accuracy: 0.4135 - val_loss: 1.5262
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.4963 - loss: 1.3726 - val_accuracy: 0.5696 - val_loss: 1.1876
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 53ms/step - accuracy: 0.5886 - loss: 1.1456 - val_accuracy: 0.5986 - val_loss: 1.1089
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.6390 - loss: 1.0234 - val_accuracy: 0.6561 - val_loss: 0.9686
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.6812 - loss: 0.9011 - val_accuracy: 0.6758 - val_loss: 0.9319
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 56ms/step - accuracy: 0.7139 - loss: 0.8144 - val_accuracy: 0.7052 - val_loss: 0.8406
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.7411 - loss: 0.7362 - val_accuracy: 0.6874 - val_loss: 0.9010
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.7630 - loss: 0.6772 - val_accuracy: 0.7166 - val_loss: 0.8380
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.7892 - loss: 0.6037 - val_accuracy: 0.7180 - val_loss: 0.8493
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.8052 - loss: 0.5550 - val_accuracy: 0.7250 - val_loss: 0.8508
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7202 - loss: 0.8667
# [0.8667029142379761, 0.7202000021934509]

# %% [markdown]
# **ZF-Net**

# %%
model = Sequential()

model.add(Conv2D(96, (3,3), strides=1, activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(384, (3,3), activation='relu'))
model.add(Conv2D(384, (3,3), activation='relu'))
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train_main, y_train_main, epochs=20, batch_size=128, validation_data=(x_val, y_val))

model.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1529/2668859418.py in <cell line: 0>()
#      24 model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#      25
# ---> 26 model.fit(x_train_main, y_train_main, epochs=20, batch_size=128, validation_data=(x_val, y_val))
#      27
#      28 model.evaluate(x_test, y_test)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#     125
#     126     return error_handler
#
# ValueError: Exception encountered when calling Conv2D.call().
#
# Negative dimension size caused by subtracting 3 from 2 for '{{node sequential_1_1/conv2d_9_1/convolution}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](sequential_1_1/conv2d_8_1/Relu, sequential_1_1/conv2d_9_1/convolution/ReadVariableOp)' with input shapes: [?,2,2,384], [3,3,384,256].
#
# Arguments received by Conv2D.call():
#   • inputs=tf.Tensor(shape=(None, 2, 2, 384), dtype=float32)

# %%
model = Sequential()

model.add(Conv2D(96, (3,3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(384, (3,3), activation='relu', padding='same'))
model.add(Conv2D(384, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train_main, y_train_main, epochs=10, batch_size=128, validation_data=(x_val, y_val))

model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.3058 - loss: 1.8372 - val_accuracy: 0.4478 - val_loss: 1.5329
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 56ms/step - accuracy: 0.5203 - loss: 1.3074 - val_accuracy: 0.5580 - val_loss: 1.2233
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.6061 - loss: 1.0991 - val_accuracy: 0.6374 - val_loss: 0.9976
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.6601 - loss: 0.9514 - val_accuracy: 0.6609 - val_loss: 0.9587
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 54ms/step - accuracy: 0.7054 - loss: 0.8374 - val_accuracy: 0.7041 - val_loss: 0.8375
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.7362 - loss: 0.7432 - val_accuracy: 0.7161 - val_loss: 0.8138
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.7654 - loss: 0.6669 - val_accuracy: 0.7310 - val_loss: 0.7691
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.7886 - loss: 0.5997 - val_accuracy: 0.7225 - val_loss: 0.8169
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.8206 - loss: 0.5177 - val_accuracy: 0.7323 - val_loss: 0.8217
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step - accuracy: 0.8356 - loss: 0.4717 - val_accuracy: 0.7454 - val_loss: 0.8330
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7251 - loss: 0.8501
# [0.8500529527664185, 0.7250999808311462]

# %% [markdown]
# **VGGNet**

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train_main, y_train_main, epochs=20, batch_size=128, validation_data=(x_val, y_val))

model.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 24s 53ms/step - accuracy: 0.3607 - loss: 1.7189 - val_accuracy: 0.5146 - val_loss: 1.3128
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.5730 - loss: 1.1972 - val_accuracy: 0.6397 - val_loss: 1.0207
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.6660 - loss: 0.9545 - val_accuracy: 0.6856 - val_loss: 0.8816
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.7229 - loss: 0.7936 - val_accuracy: 0.7298 - val_loss: 0.7691
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.7656 - loss: 0.6687 - val_accuracy: 0.7602 - val_loss: 0.6836
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.8027 - loss: 0.5630 - val_accuracy: 0.7758 - val_loss: 0.6585
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.8359 - loss: 0.4751 - val_accuracy: 0.7825 - val_loss: 0.6376
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.8648 - loss: 0.3903 - val_accuracy: 0.7834 - val_loss: 0.6673
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.8870 - loss: 0.3209 - val_accuracy: 0.7755 - val_loss: 0.7025
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.9068 - loss: 0.2632 - val_accuracy: 0.7912 - val_loss: 0.7588
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.9198 - loss: 0.2255 - val_accuracy: 0.7886 - val_loss: 0.7878
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9337 - loss: 0.1892 - val_accuracy: 0.7913 - val_loss: 0.8336
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9452 - loss: 0.1567 - val_accuracy: 0.7797 - val_loss: 0.9012
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9488 - loss: 0.1447 - val_accuracy: 0.7910 - val_loss: 0.8938
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9574 - loss: 0.1235 - val_accuracy: 0.7888 - val_loss: 0.9973
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9525 - loss: 0.1381 - val_accuracy: 0.7808 - val_loss: 0.9629
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9622 - loss: 0.1102 - val_accuracy: 0.7783 - val_loss: 1.0863
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9654 - loss: 0.1037 - val_accuracy: 0.7797 - val_loss: 1.0292
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9685 - loss: 0.0922 - val_accuracy: 0.7872 - val_loss: 1.1325
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9686 - loss: 0.0937 - val_accuracy: 0.7911 - val_loss: 1.1207
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7831 - loss: 1.1933
# [1.1933379173278809, 0.7831000089645386]

# %% [markdown]
# **GoogLeNet**

# %%
from keras.layers import Input, concatenate
from keras.models import Model

input_layer = Input(shape=(32,32,3))

conv1 = Conv2D(64, (1,1), activation='relu', padding='same')(input_layer)

conv3 = Conv2D(64, (1,1), activation='relu', padding='same')(input_layer)
conv3 = Conv2D(128, (3,3), activation='relu', padding='same')(conv3)

conv5 = Conv2D(16, (1,1), activation='relu', padding='same')(input_layer)
conv5 = Conv2D(32, (5,5), activation='relu', padding='same')(conv5)

pool = MaxPooling2D((3,3), strides=1, padding='same')(input_layer)
pool = Conv2D(32, (1,1), activation='relu', padding='same')(pool)

output = concatenate([conv1, conv3, conv5, pool])

x = Flatten()(output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)

output = Dense(10, activation='softmax')(x)

model = Model(inputs=input_layer, outputs=output)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train_main, y_train_main, epochs=20, batch_size=128, validation_data=(x_val, y_val))

model.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 30s 66ms/step - accuracy: 0.1869 - loss: 2.4384 - val_accuracy: 0.2927 - val_loss: 1.8979
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.2248 - loss: 1.9898 - val_accuracy: 0.3197 - val_loss: 1.8765
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.2477 - loss: 1.9232 - val_accuracy: 0.3371 - val_loss: 1.7427
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - accuracy: 0.2676 - loss: 1.8680 - val_accuracy: 0.3952 - val_loss: 1.6236
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.2967 - loss: 1.7894 - val_accuracy: 0.4441 - val_loss: 1.5630
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - accuracy: 0.3312 - loss: 1.7162 - val_accuracy: 0.4659 - val_loss: 1.5047
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - accuracy: 0.3544 - loss: 1.6605 - val_accuracy: 0.4929 - val_loss: 1.4435
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.3844 - loss: 1.6010 - val_accuracy: 0.5129 - val_loss: 1.3726
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.4162 - loss: 1.5268 - val_accuracy: 0.5232 - val_loss: 1.3480
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.4400 - loss: 1.4631 - val_accuracy: 0.5536 - val_loss: 1.2786
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.4685 - loss: 1.4037 - val_accuracy: 0.5539 - val_loss: 1.2674
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.4902 - loss: 1.3505 - val_accuracy: 0.5657 - val_loss: 1.2303
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.5108 - loss: 1.3065 - val_accuracy: 0.5732 - val_loss: 1.2208
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.5257 - loss: 1.2626 - val_accuracy: 0.5789 - val_loss: 1.1963
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.5394 - loss: 1.2301 - val_accuracy: 0.5931 - val_loss: 1.1719
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.5549 - loss: 1.1882 - val_accuracy: 0.5955 - val_loss: 1.1828
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.5754 - loss: 1.1359 - val_accuracy: 0.6020 - val_loss: 1.1670
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.5883 - loss: 1.1045 - val_accuracy: 0.5932 - val_loss: 1.1815
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.6025 - loss: 1.0611 - val_accuracy: 0.6159 - val_loss: 1.1384
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 48ms/step - accuracy: 0.6168 - loss: 1.0189 - val_accuracy: 0.6126 - val_loss: 1.1381
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6134 - loss: 1.1218
# [1.1217843294143677, 0.6133999824523926]

# %% [markdown]
# **ResNet**

# %%
from keras.layers import Add

def residual_block(x, filters):
    shortcut = x

    x = Conv2D(filters, (3,3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x)

    x = Conv2D(filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)

    x = Add()([x, shortcut])
    x = keras.activations.relu(x)

    return x

input_layer = Input(shape=(32,32,3))

x = Conv2D(32, (3,3), padding='same', activation='relu')(input_layer)

x = residual_block(x, 32)
x = residual_block(x, 32)

x = MaxPooling2D((2,2))(x)

x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)

output = Dense(10, activation='softmax')(x)

model = Model(inputs=input_layer, outputs=output)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train_main, y_train_main, epochs=20, batch_size=128, validation_data=(x_val, y_val))

model.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.2075 - loss: 2.2770 - val_accuracy: 0.1558 - val_loss: 2.1804
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.2673 - loss: 1.8786 - val_accuracy: 0.3538 - val_loss: 1.8097
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.2938 - loss: 1.8059 - val_accuracy: 0.3708 - val_loss: 1.7299
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3043 - loss: 1.7505 - val_accuracy: 0.4255 - val_loss: 1.5578
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3224 - loss: 1.7096 - val_accuracy: 0.4691 - val_loss: 1.4575
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.3288 - loss: 1.6892 - val_accuracy: 0.4813 - val_loss: 1.4894
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3424 - loss: 1.6592 - val_accuracy: 0.5005 - val_loss: 1.3758
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.3522 - loss: 1.6493 - val_accuracy: 0.5422 - val_loss: 1.3398
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.3641 - loss: 1.6237 - val_accuracy: 0.5158 - val_loss: 1.4428
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.3720 - loss: 1.6069 - val_accuracy: 0.4842 - val_loss: 1.3845
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.3824 - loss: 1.5805 - val_accuracy: 0.5686 - val_loss: 1.3123
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3871 - loss: 1.5711 - val_accuracy: 0.4844 - val_loss: 1.7077
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3883 - loss: 1.5604 - val_accuracy: 0.5692 - val_loss: 1.2362
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.3920 - loss: 1.5487 - val_accuracy: 0.5262 - val_loss: 1.4285
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3995 - loss: 1.5395 - val_accuracy: 0.5962 - val_loss: 1.2497
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4027 - loss: 1.5281 - val_accuracy: 0.5918 - val_loss: 1.2761
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4070 - loss: 1.5216 - val_accuracy: 0.5965 - val_loss: 1.2632
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4123 - loss: 1.5003 - val_accuracy: 0.5724 - val_loss: 1.2924
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4139 - loss: 1.4980 - val_accuracy: 0.5806 - val_loss: 1.2309
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4187 - loss: 1.4866 - val_accuracy: 0.5455 - val_loss: 1.4228
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5400 - loss: 1.4110
# [1.4110428094863892, 0.5400000214576721]

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor()
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)

model = torchvision.models.resnet18(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

model.fc = nn.Linear(512, 10)

model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc.parameters(), lr=0.001)

for epoch in range(5):
    model.train()
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print("Epoch:", epoch+1, "Loss:", loss.item())
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 46.8MB/s]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 176MB/s]
# Epoch: 1 Loss: 0.3886232078075409
# Epoch: 2 Loss: 0.4322819113731384
# Epoch: 3 Loss: 0.5704495906829834
# Epoch: 4 Loss: 0.5386103987693787
# Epoch: 5 Loss: 0.21949279308319092

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print("Test Accuracy:", 100 * correct / total)
# Out:
# Test Accuracy: 80.03
